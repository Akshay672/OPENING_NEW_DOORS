# %% [markdown]
# # <b>OPENING NEW DOORS</b>

# %% [markdown]
# <b>Subway</b> (also known as Doctor's Associates Inc) is an American privately held restaurant franchise that primarily sells submarine sandwiches (subs), salads and beverages.

# %% [markdown]
# <b>PROJECT ANALYSIS</b>

# %% [markdown]
# In this project where we have constructed a dataset containing detailed information of country's State name and their respective Districts.
#
# Also provides us with an information on population of Male and Female and their Literacy and number of Male and Female Workers sorted with respect to their Age groups.
#
# Our Intention is clear too set up <b>3</b> more subway stores in major cities to expand our Business and grow with our Culnaries.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <b>DATASET</b>

# %%
df=pd.read_csv('India-Districts-Census-2020.csv')
df
# Out:
#     District code         State name     District name  Population      Male  \
# 0              21  JAMMU AND KASHMIR             Jammu    13769622   7324389
# 1              24   HIMACHAL PRADESH            Kangra    13590675   6755319
# 2              35             PUNJAB         Gurdaspur    20684907  10913553
# 3              55         CHANDIGARH        Chandigarh     9499050   5225967
# 4              88            HARYANA         Faridabad    16287597   8694990
# 5              99          RAJASTHAN        Ganganagar    17722512   9390060
# 6             132      UTTAR PRADESH        Saharanpur    31197438  16506954
# 7             248  ARUNACHAL PRADESH        Papum Pare     1589157    802638
# 8             265           NAGALAND           Dimapur     3409299   1776546
# 9             277            MANIPUR       Imphal West     4661928   2295486
# 10            283            MIZORAM            Aizawl     3602781   1793430
# ...

# %% [markdown]
# <b>EMBEDDING TABLEU WORKBOOK IN JUPYTER NOTEBOOK</b>

# %% [markdown]
# In order to explain the story line and the conclusions in brief, we have embedded tableu with jupyter notebook

# %%
# %%HTML
# <div class='tableauPlaceholder' id='viz1607964122655' style='position: relative'><noscript><a href='#'><img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Wa&#47;Wallmart_sales_analysis&#47;Dashboard1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='Wallmart_sales_analysis&#47;Dashboard1' /><param name='tabs' value='yes' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Wa&#47;Wallmart_sales_analysis&#47;Dashboard1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1607964122655');                    var vizElement = divElement.getElementsByTagName('object')[0];                    if ( divElement.offsetWidth > 800 ) { vizElement.style.minWidth='1000px';vizElement.style.maxWidth='100%';vizElement.style.minHeight='850px';vizElement.style.maxHeight=(divElement.offsetWidth*0.75)+'px';} else if ( divElement.offsetWidth > 500 ) { vizElement.style.minWidth='1000px';vizElement.style.maxWidth='100%';vizElement.style.minHeight='850px';vizElement.style.maxHeight=(divElement.offsetWidth*0.75)+'px';} else { vizElement.style.width='100%';vizElement.style.minHeight='2050px';vizElement.style.maxHeight=(divElement.offsetWidth*1.77)+'px';}                     var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>
# Out:
# <div class='tableauPlaceholder' id='viz1607964122655' style='position: relative'><noscript><a href='#'><img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Wa&#47;Wallmart_sales_analysis&#47;Dashboard1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='Wallmart_sales_analysis&#47;Dashboard1' /><param name='tabs' value='yes' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Wa&#47;Wallmart_sales_analysis&#47;Dashboard1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' 
# ...

# %% [markdown]
# <b>TABLEU TAB 1: DISTRICT WISE POPULATION</b>

# %% [markdown]
# We have incured the location of every district and their size of Total population.

# %% [markdown]
# <b>TABLEU TAB 2: STATE  WISE DISTRICT POPUALTION</b>

# %% [markdown]
# From the Visulization we have fetched the name of state, district and its population sorted form highest to the lowest.
#
# FIltered Top 5 Districts with the highest population are:<br>
# Malappuram<br>
# Raipur<br>
# Jalpaiguri<br>
# Thiruvallur<br>
# Ganjam

# %% [markdown]
# <b>TABLEU TAB 3: FEMALE LITERATE</b>

# %% [markdown]
# From the Pie-chart, we have filtered the top 5 district with highest female Literacy are:<br><br>
# Malappuram<br>
# Thiruvallur<br>
# Raipur<br>
# Jalpaiguri<br>
# Indore<br>
#
# Based on the Percentage, we can visualize that Malappuram has <b>27.34%</b> litercay of the total 5 districts.

# %% [markdown]
# <b>TABLEU TAB 4: MALE LITERATE</b>

# %% [markdown]
# From the Pie-chart, we have filtered the top 5 district with highest male Literacy are:<br><br>
# Malappuram<br>
# Thiruvallur<br>
# Raipur<br>
# Jalpaiguri<br>
# Indore<br>
#
# Based on the Percentage, we can visualize that Malappuram has <b>21.965%</b> litercay of the total 5 districts.

# %% [markdown]
# <b>TABLEU TAB 5: AGE GROUP POPULATION 0 - 29 Years</b>

# %% [markdown]
# For Population Age Group between 0 - 29 years, after filtering Raipur has the highest Population of 22088691.

# %% [markdown]
# <b>TABLEU TAB 6: AGE GROUP POPULATION 30 - 49 Years</b>

# %% [markdown]
# For Population Age Group between 30 - 49 years, after filtering Thiruvallur has the highest Population of 10392975.

# %% [markdown]
# <b>TABLEU TAB 7: AGE GROUP POPULATION 50 AND ABOVE Years</b>

# %% [markdown]
# For Population Age Group between 50 and above years, after filtering Malappuram has the highest Population of 5960799.

# %% [markdown]
# <b>TABLEU TAB 8: AVERAGE FEMALE WORKING POPULATION</b>

# %% [markdown]
# In Bubble chart we have filtered the top 5 districts on the working population of females, on average Raipur has the
# highest number of female working.

# %% [markdown]
# <b>TABLEU TAB 9: AVERAGE MALE WORKING POPULATION</b>

# %% [markdown]
# In Bubble chart we have filtered the top 5 districts on the working population of males, on average Raipur, Thiruvallur, Jalpaiguri are in the maximum range of male working

# %% [markdown]
# <b>CONCLUSION</b>

# %% [markdown]
# Upon the above Visulization
#
# <b>Raipur</b>
# 1. It is ranked 2nd in terms of Population.
# 2. It has a good literacy rate in terms of both male and female.
# 3. It has the highest population in the age group of 0 to 29.
# 4. It has the highest working Population

# %% [markdown]
# <b>Thiruvallur</b>
# 1. It is ranked 4th in terms of Population.
# 2. It has a good literacy rate in terms of both male and female.
# 3. It has the highest population in the age group of 30 to 49.
# 4. It has the highest Male working Population.

# %% [markdown]
# <b>Malappuram</b>
# 1. It is ranked 1st in terms of Population.
# 2. It has a best literacy rate in terms of both male and female.
# 3. It has the highest population in the age group of 50 and above.

# %% [markdown]
# <b>Jalpaiguri</b>
# 1. It is ranked 3rd in terms of Population.
# 2. It has a better literacy rate in terms of both male and female.
# 3. It has the highest Male working Population.

# %% [markdown]
# From the above conclusions we can draw that <b>Raipur</b> and <b>Thiruvallur</b>  are the main hotspots to establish the business first.
#
# There is tie between <b>Malappuram</b> and <b>Jalpaiguri</b> as they balance equally in some aspects.
